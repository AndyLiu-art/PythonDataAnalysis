# %% [markdown]
# ### 绘制核密度估计曲线

# %%
# 导入基础计算库
import numpy as np
# 导入数据分析库
import pandas as pd

# %%
# 设置随机数种子
np.random.seed(1)
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()
# Out:
# <Axes: ylabel='Density'>
