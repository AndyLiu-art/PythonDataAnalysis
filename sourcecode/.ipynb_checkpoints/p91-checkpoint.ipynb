# %% [markdown]
# ### 自定义高亮显示数据

# %%
# 导入基础计算库
import numpy as np
# 导入数据分析库
import pandas as pd
# 导入matplotlib包
import matplotlib as mpl

# %%
# 设置随机数种子
np.random.seed(1)
# 生成数据
weather_df = pd.DataFrame(
    np.random.rand(10,2)*5,
    index=pd.date_range(start="2021-01-01", periods=10),
    columns=["Tokyo", "Beijing"]
)
# 自定义函数
def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"
# 高亮显示
def make_pretty(styler):
    styler.set_caption("Weather Conditions") # 设置数据表的标题
    styler.format(rain_condition) # 设置数据格式，调用自定义函数
    styler.format_index(lambda v: v.strftime("%A")) # 修改行名
    # 背景颜色
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

weather_df
# Out:
#                Tokyo   Beijing
# 2021-01-01  2.085110  3.601622
# 2021-01-02  0.000572  1.511663
# 2021-01-03  0.733779  0.461693
# 2021-01-04  0.931301  1.727804
# 2021-01-05  1.983837  2.694084
# 2021-01-06  2.095973  3.426098
# 2021-01-07  1.022261  4.390587
# 2021-01-08  0.136938  3.352338
# 2021-01-09  2.086524  2.793449
# 2021-01-10  0.701935  0.990507

# %%
# 高亮显示，调用make_pretty函数
weather_df.loc["2021-01-04":"2021-01-08"].style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_295df_row0_col0, #T_295df_row4_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_295df_row0_col1 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_295df_row1_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_295df_row1_col1 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_295df_row2_col0 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_295df_row2_col1 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_295df_row3_col0 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_295df_row3_col1 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_295df_row4_col1 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_295df">
#   <caption>Weather Conditions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_295df_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_295df_level0_col1" class="col_heading level0 col1" >Beijing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_295df_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_295df_row0_col0" class="data row0 col0" >Dry</td>
#       <td id="T_295df_row0_col1" class="data row0 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_295df_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_295df_row1_col0" class="data row1 col0" >Rain</td>
#       <td id="T_295df_row1_col1" class="data row1 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_295df_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_295df_row2_col0" class="data row2 col0" >Rain</td>
#       <td id="T_295df_row2_col1" class="data row2 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_295df_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_295df_row3_col0" class="data row3 col0" >Dry</td>
#       <td id="T_295df_row3_col1" class="data row3 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_295df_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_295df_row4_col0" class="data row4 col0" >Dry</td>
#       <td id="T_295df_row4_col1" class="data row4 col1" >Heavy Rain</td>
#     </tr>
#   </tbody>
# </table>
