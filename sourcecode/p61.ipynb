# %% [markdown]
# ### 绘制线图

# %%
# 导入基础计算库
import numpy as np
# 导入数据分析库
import pandas as pd

# %%
# 设置随机数种子
np.random.seed(123456)
# 生成数据
ts = pd.Series(
    np.random.randn(1000), # 数字
    index=pd.date_range("1/1/2000", periods=1000) # 时间
)
# 累加
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >
