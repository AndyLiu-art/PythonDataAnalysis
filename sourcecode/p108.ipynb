# %% [markdown]
# ### 在dataframe上使用鼠标互动

# %%
# 导入基础计算库
import numpy as np
# 导入数据分析库
import pandas as pd
# 导入matplotlib包
import matplotlib as mpl

# %%
# 设置随机数种子
np.random.seed(0)
# 生成数据
df = pd.DataFrame(np.random.randn(10,4), columns=["A","B","C","D"])
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc8fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc8fd_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_cc8fd_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_cc8fd_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_cc8fd_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc8fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc8fd_row0_col0" class="data row0 col0" >1.764052</td>
#       <td id="T_cc8fd_row0_col1" class="data row0 col1" >0.400157</td>
#       <td id="T_cc8fd_row0_col2" class="data row0 col2" >0.978738</td>
#       <td id="T_cc8fd_row0_col3" class="data row0 col3" >2.240893</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc8fd_row1_col0" class="data row1 col0" >1.867558</td>
#       <td id="T_cc8fd_row1_col1" class="data row1 col1" >-0.977278</td>
#       <td id="T_cc8fd_row1_col2" class="data row1 col2" >0.950088</td>
#       <td id="T_cc8fd_row1_col3" class="data row1 col3" >-0.151357</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc8fd_row2_col0" class="data row2 col0" >-0.103219</td>
#       <td id="T_cc8fd_row2_col1" class="data row2 col1" >0.410599</td>
#       <td id="T_cc8fd_row2_col2" class="data row2 col2" >0.144044</td>
#       <td id="T_cc8fd_row2_col3" class="data row2 col3" >1.454274</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc8fd_row3_col0" class="data row3 col0" >0.761038</td>
#       <td id="T_cc8fd_row3_col1" class="data row3 col1" >0.121675</td>
#       <td id="T_cc8fd_row3_col2" class="data row3 col2" >0.443863</td>
#       <td id="T_cc8fd_row3_col3" class="data row3 col3" >0.333674</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc8fd_row4_col0" class="data row4 col0" >1.494079</td>
#       <td id="T_cc8fd_row4_col1" class="data row4 col1" >-0.205158</td>
#       <td id="T_cc8fd_row4_col2" class="data row4 col2" >0.313068</td>
#       <td id="T_cc8fd_row4_col3" class="data row4 col3" >-0.854096</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc8fd_row5_col0" class="data row5 col0" >-2.552990</td>
#       <td id="T_cc8fd_row5_col1" class="data row5 col1" >0.653619</td>
#       <td id="T_cc8fd_row5_col2" class="data row5 col2" >0.864436</td>
#       <td id="T_cc8fd_row5_col3" class="data row5 col3" >-0.742165</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc8fd_row6_col0" class="data row6 col0" >2.269755</td>
#       <td id="T_cc8fd_row6_col1" class="data row6 col1" >-1.454366</td>
#       <td id="T_cc8fd_row6_col2" class="data row6 col2" >0.045759</td>
#       <td id="T_cc8fd_row6_col3" class="data row6 col3" >-0.187184</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cc8fd_row7_col0" class="data row7 col0" >1.532779</td>
#       <td id="T_cc8fd_row7_col1" class="data row7 col1" >1.469359</td>
#       <td id="T_cc8fd_row7_col2" class="data row7 col2" >0.154947</td>
#       <td id="T_cc8fd_row7_col3" class="data row7 col3" >0.378163</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cc8fd_row8_col0" class="data row8 col0" >-0.887786</td>
#       <td id="T_cc8fd_row8_col1" class="data row8 col1" >-1.980796</td>
#       <td id="T_cc8fd_row8_col2" class="data row8 col2" >-0.347912</td>
#       <td id="T_cc8fd_row8_col3" class="data row8 col3" >0.156349</td>
#     </tr>
#     <tr>
#       <th id="T_cc8fd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cc8fd_row9_col0" class="data row9 col0" >1.230291</td>
#       <td id="T_cc8fd_row9_col1" class="data row9 col1" >1.202380</td>
#       <td id="T_cc8fd_row9_col2" class="data row9 col2" >-0.387327</td>
#       <td id="T_cc8fd_row9_col3" class="data row9 col3" >-0.302303</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 鼠标停留时，行高和列宽增大的函数
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "10pt")]),
            dict(selector="td",
                 props=[('padding', "8em 8em")]),
            dict(selector="th:hover",
                 props=[("font-size", "10pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '5px'),
                        ('font-size', '5pt')])
]

# %%
np.random.seed(25)
import seaborn as sns
cmap = sns.diverging_palette(5, 250, as_cmap=True)
df.style.background_gradient(
    cmap, axis=1
).set_properties(
    **{
        "max-width": "80px", "font-size": "1pt"
    }
).set_caption(
    "Hover to magnify"
).format(
    precision=2
).set_table_styles(magnify())
# Out:
# <style type="text/css">
# #T_ce2d9 th {
#   font-size: 10pt;
# }
# #T_ce2d9 td {
#   padding: 8em 8em;
# }
# #T_ce2d9 th:hover {
#   font-size: 10pt;
# }
# #T_ce2d9 tr:hover td:hover {
#   max-width: 5px;
#   font-size: 5pt;
# }
# #T_ce2d9_row0_col0 {
#   background-color: #9eb8d8;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row0_col1, #T_ce2d9_row1_col1, #T_ce2d9_row2_col0, #T_ce2d9_row3_col1, #T_ce2d9_row4_col3, #T_ce2d9_row5_col0, #T_ce2d9_row6_col1, #T_ce2d9_row7_col2, #T_ce2d9_row8_col1, #T_ce2d9_row9_col2 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row0_col2 {
#   background-color: #e8aeba;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row0_col3, #T_ce2d9_row1_col0, #T_ce2d9_row2_col3, #T_ce2d9_row3_col0, #T_ce2d9_row4_col0, #T_ce2d9_row5_col2, #T_ce2d9_row6_col0, #T_ce2d9_row7_col0, #T_ce2d9_row8_col3, #T_ce2d9_row9_col0 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row1_col2 {
#   background-color: #b4c7df;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row1_col3 {
#   background-color: #e7a5b2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row2_col1, #T_ce2d9_row3_col3 {
#   background-color: #e9b4be;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row2_col2 {
#   background-color: #e0748a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row3_col2 {
#   background-color: #eff0f2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row4_col1 {
#   background-color: #e6a0ae;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row4_col2 {
#   background-color: #f2f1f1;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row5_col1 {
#   background-color: #5887c1;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row5_col3 {
#   background-color: #e7eaef;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row6_col2 {
#   background-color: #edcfd5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row6_col3 {
#   background-color: #eab8c2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row7_col1 {
#   background-color: #5383bf;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row7_col3 {
#   background-color: #e0768b;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row8_col0 {
#   background-color: #eeeff2;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row8_col2 {
#   background-color: #95b1d5;
#   color: #000000;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row9_col1 {
#   background-color: #497dbc;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# #T_ce2d9_row9_col3 {
#   background-color: #da4e6a;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 1pt;
# }
# </style>
# <table id="T_ce2d9">
#   <caption>Hover to magnify</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce2d9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ce2d9_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ce2d9_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ce2d9_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce2d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce2d9_row0_col0" class="data row0 col0" >1.76</td>
#       <td id="T_ce2d9_row0_col1" class="data row0 col1" >0.40</td>
#       <td id="T_ce2d9_row0_col2" class="data row0 col2" >0.98</td>
#       <td id="T_ce2d9_row0_col3" class="data row0 col3" >2.24</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce2d9_row1_col0" class="data row1 col0" >1.87</td>
#       <td id="T_ce2d9_row1_col1" class="data row1 col1" >-0.98</td>
#       <td id="T_ce2d9_row1_col2" class="data row1 col2" >0.95</td>
#       <td id="T_ce2d9_row1_col3" class="data row1 col3" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce2d9_row2_col0" class="data row2 col0" >-0.10</td>
#       <td id="T_ce2d9_row2_col1" class="data row2 col1" >0.41</td>
#       <td id="T_ce2d9_row2_col2" class="data row2 col2" >0.14</td>
#       <td id="T_ce2d9_row2_col3" class="data row2 col3" >1.45</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce2d9_row3_col0" class="data row3 col0" >0.76</td>
#       <td id="T_ce2d9_row3_col1" class="data row3 col1" >0.12</td>
#       <td id="T_ce2d9_row3_col2" class="data row3 col2" >0.44</td>
#       <td id="T_ce2d9_row3_col3" class="data row3 col3" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce2d9_row4_col0" class="data row4 col0" >1.49</td>
#       <td id="T_ce2d9_row4_col1" class="data row4 col1" >-0.21</td>
#       <td id="T_ce2d9_row4_col2" class="data row4 col2" >0.31</td>
#       <td id="T_ce2d9_row4_col3" class="data row4 col3" >-0.85</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce2d9_row5_col0" class="data row5 col0" >-2.55</td>
#       <td id="T_ce2d9_row5_col1" class="data row5 col1" >0.65</td>
#       <td id="T_ce2d9_row5_col2" class="data row5 col2" >0.86</td>
#       <td id="T_ce2d9_row5_col3" class="data row5 col3" >-0.74</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce2d9_row6_col0" class="data row6 col0" >2.27</td>
#       <td id="T_ce2d9_row6_col1" class="data row6 col1" >-1.45</td>
#       <td id="T_ce2d9_row6_col2" class="data row6 col2" >0.05</td>
#       <td id="T_ce2d9_row6_col3" class="data row6 col3" >-0.19</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce2d9_row7_col0" class="data row7 col0" >1.53</td>
#       <td id="T_ce2d9_row7_col1" class="data row7 col1" >1.47</td>
#       <td id="T_ce2d9_row7_col2" class="data row7 col2" >0.15</td>
#       <td id="T_ce2d9_row7_col3" class="data row7 col3" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce2d9_row8_col0" class="data row8 col0" >-0.89</td>
#       <td id="T_ce2d9_row8_col1" class="data row8 col1" >-1.98</td>
#       <td id="T_ce2d9_row8_col2" class="data row8 col2" >-0.35</td>
#       <td id="T_ce2d9_row8_col3" class="data row8 col3" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_ce2d9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce2d9_row9_col0" class="data row9 col0" >1.23</td>
#       <td id="T_ce2d9_row9_col1" class="data row9 col1" >1.20</td>
#       <td id="T_ce2d9_row9_col2" class="data row9 col2" >-0.39</td>
#       <td id="T_ce2d9_row9_col3" class="data row9 col3" >-0.30</td>
#     </tr>
#   </tbody>
# </table>
